# %%
import time
import os, sys
import matplotlib.pyplot as plt
import librosa.display

from coughvid_dataset import CoughvidDataset

PATH_TO_DATASET = "D:\COUGHVID_public_dataset\public_dataset"
mask_dir = "D:\COUGHVID_public_dataset\segmentation.npy"

# %%
covid_set = CoughvidDataset(PATH_TO_DATASET, mask_dir)
x, mask = covid_set[78] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# 10817 records ready to load.
# D:\COUGHVID_public_dataset\public_dataset\0200e61f-0937-4044-a7d5-53d5855ae29e.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[143] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\03b402a3-5318-4289-b746-7bfa40546709.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[502] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\0c00c8ed-66c1-45db-b61d-12bca483b220.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[26] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\00ac8cb0-3384-46b2-9db5-5b5e911615f0.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[56] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\01695001-bbab-4bf4-b88f-7372c0b64bb2.webm
# [False False False ... False False False]
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[750] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\1262a32f-65ff-452b-8c6a-f1a1d14c31a4.webm
# [False False False ... False False False]
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[365] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\0908fd5c-9e5c-440b-a90d-832d76899be0.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[1759] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\2b3c2842-8efc-422f-b841-8c59f4b48d3c.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')

# %%
x, mask = covid_set[546] #I randomly try with one of the instance in the database

plt.figure(figsize=(14, 5))

plt.plot(x)
plt.plot(mask)
plt.title("Segmentation Output")
# Out:
# D:\COUGHVID_public_dataset\public_dataset\0d0f9fbe-1644-4452-90f6-aff43c06d1ad.webm
# [False False False ... False False False]
# C:\Users\patri\CoughVid\coughvid_dataset.py:125: RuntimeWarning: divide by zero encountered in log2
#   return np.log2(np.sum(np.power(frame,2)))
# Text(0.5, 1.0, 'Segmentation Output')
